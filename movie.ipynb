# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
movies = movies.merge(credits, on='title')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
#genres
#id
#keywords
#title
#overview
#cast
#crew
movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   overview  4806 non-null   object
#  3   genres    4809 non-null   object
#  4   keywords  4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def convert(obj):
    L=[]
    counter=0
    for i in ast.literal_eval(obj):
        if counter<3:
            L.append(i['name'])
            counter+=1
    return L

# %%
import ast

movies['genres'] = movies['genres'].apply(convert)

# %%
movies['keywords']= movies['keywords'].apply(convert)

# %%
movies['cast']= movies['cast'].apply(convert)

# %%
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                          genres                            keywords  \
# 0  [Action, Adventure, Fantasy]  [culture clash, future, space war]
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
def fetch_director(obj):
    L=[]
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            L.append(i['name'])
            break
    return L

# %%
movies['crew']= movies['crew'].apply(fetch_director)

# %%
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                          genres                            keywords  \
# 0  [Action, Adventure, Fantasy]  [culture clash, future, space war]
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies['overview']= movies['overview'].apply(lambda x:x.split())

# %%
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  [In, the, 22nd, century,, a, paraplegic, Marin...
#
#                          genres                            keywords  \
# 0  [Action, Adventure, Fantasy]  [culture clash, future, space war]
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['crew'] = movies['crew'].apply(lambda x: [i.replace(" ", "") for i in x])

movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  [In, the, 22nd, century,, a, paraplegic, Marin...
#
#                          genres                          keywords  \
# 0  [Action, Adventure, Fantasy]  [cultureclash, future, spacewar]
#
#                                             cast  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]
#
#                                                 crew  \
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...

# %%
new_df=movies[['movie_id','title','tags']]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\VENKATA PAVANI\AppData\Local\Temp\ipykernel_14052\1824047427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))

# %%
new_df.head(1)
# Out:
#    movie_id   title                                               tags
# 0     19995  Avatar  I n   t h e   2 2 n d   c e n t u r y ,   a   ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: x.lower())
# Out:
# C:\Users\VENKATA PAVANI\AppData\Local\Temp\ipykernel_14052\1380776331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: x.lower())

# %%
new_df.head(1)
# Out:
#    movie_id   title                                               tags
# 0     19995  Avatar  i n   t h e   2 2 n d   c e n t u r y ,   a   ...

# %%
new_df['tags'][0]
# Out:
# 'i n   t h e   2 2 n d   c e n t u r y ,   a   p a r a p l e g i c   m a r i n e   i s   d i s p a t c h e d   t o   t h e   m o o n   p a n d o r a   o n   a   u n i q u e   m i s s i o n ,   b u t   b e c o m e s   t o r n   b e t w e e n   f o l l o w i n g   o r d e r s   a n d   p r o t e c t i n g   a n   a l i e n   c i v i l i z a t i o n .   a c t i o n   a d v e n t u r e   f a n t a s y   c u l t u r e c l a s h   f u t u r e   s p a c e w a r   s a m w o r t h i n g t o n   z o e s a l d a n a   s i g o u r n e y w e a v e r   [   {   "   c   r   e   d   i   t   _   i   d   "   :     "   5   2   f   e   4   8   0   0   9   2   5   1   4   1   6   c   7   5   0   a   c   a   2   3   "   ,     "   d   e   p   a   r   t   m   e   n   t   "   :     "   e   d   i   t   i   n   g   "   ,     "   g   e   n   d   e   r   "   :     0   ,     "   i   d   "   :     1   7   2   1   ,     "   j   o   b   "   :     "   e   d   i   t   o   r   "   ,     "   n   a   m   e   "   :     "  
# ...

# %%
new_df['tags'].isnull().sum()
new_df['tags'] = new_df['tags'].fillna('')
new_df['tags'] = new_df['tags'].astype(str)
# Out:
# C:\Users\VENKATA PAVANI\AppData\Local\Temp\ipykernel_14052\2978390668.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].fillna('')
# C:\Users\VENKATA PAVANI\AppData\Local\Temp\ipykernel_14052\2978390668.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].astype(str)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
cv.fit_transform(new_df['tags']).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 cv.fit_transform(new_df['tags']).toarray()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\feature_extraction\text.py:1376, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1368             warnings.warn(
#    1369                 "Upper case characters found in"
#    1370                 " vocabulary while 'lowercase'"
# ...

# %%
print('overview type:', type(movies.loc[0, 'overview']))
print('genres type:', type(movies.loc[0, 'genres']))
print('keywords type:', type(movies.loc[0, 'keywords']))
print('cast type:', type(movies.loc[0, 'cast']))
print('crew type:', type(movies.loc[0, 'crew']))
print('overview sample:', repr(movies.loc[0, 'overview'][:20]))
print('genres sample:', movies.loc[0, 'genres'][:10])
print('keywords sample:', movies.loc[0, 'keywords'][:10])
print('cast sample:', movies.loc[0, 'cast'][:10])
print('crew sample:', movies.loc[0, 'crew'][:10])
print('movie tags type before join:', type(movies.loc[0, 'tags']))
print('movie tags sample before join:', repr(movies.loc[0, 'tags'][:50]))
print('\nvalue counts by type for tags:', movies['tags'].apply(type).value_counts())
print('overview types:', movies['overview'].apply(type).value_counts())
print('genres types:', movies['genres'].apply(type).value_counts())
print('keywords types:', movies['keywords'].apply(type).value_counts())
print('cast types:', movies['cast'].apply(type).value_counts())
print('crew types:', movies['crew'].apply(type).value_counts())
# Out:
# overview type: <class 'list'>
# genres type: <class 'list'>
# keywords type: <class 'list'>
# cast type: <class 'list'>
# crew type: <class 'list'>
# overview sample: ['In', 'the', '22nd', 'century,', 'a', 'paraplegic', 'Marine', 'is', 'dispatched', 'to', 'the', 'moon', 'Pandora', 'on', 'a', 'unique', 'mission,', 'but', 'becomes', 'torn']
# genres sample: ['Action', 'Adventure', 'Fantasy']
# keywords sample: ['cultureclash', 'future', 'spacewar']
# cast sample: ['SamWorthington', 'ZoeSaldana', 'SigourneyWeaver']
# crew sample: ['[', '{', '"', 'c', 'r', 'e', 'd', 'i', 't', '_']
# movie tags type before join: <class 'list'>
# ...
